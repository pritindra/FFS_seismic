# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data1.csv')
df.head()
# Out:
#          Date     Time  Latitude  Longitude  Depth  Magnitude
# 0  01/01/1966  25:51.1       0.6      -25.4   33.0        4.9
# 1  02/01/1966  33:08.6      38.2       57.1   58.0        4.1
# 2  02/01/1966  12:16.7      37.6       23.2    7.0        4.9
# 3  13/01/1966  44:12.6      38.4       28.5   33.0        4.4
# 4  14/01/1966  39:30.8      34.6       27.0   33.0        4.8

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot(x='Depth', y='Magnitude', kind='scatter')
# Out:
# <AxesSubplot:xlabel='Depth', ylabel='Magnitude'>
